# %%
def infoUser( age ,name ="tspeeh" ):
    '''docs string important for ai agant
    this fun take the name and the age
    Args:
    name(str) : name of user
    age (int ):age of user

    return (str)
    '''
    return f"his name is {name} and the age is {age}"

# %%
def dictdata(**name):
    print(name)
    print(type(name))

# %%
def model(*tupledata, **dictdata):
   
   print("tupledata:")
   for i in tupledata:
    print(i)
   print("dictdata:")
   for key , value in dictdata.items():
       print(f"{key} : {value}")

# %%
trans={
    "lower": lambda text: text.lower(),
    "upper": lambda text: text.upper(),
}
text = "Hello, World!"
print(trans["lower"]("OFJFKFCNL"))
print(trans["upper"](text))
# Out:
# ofjfkfcnl
# HELLO, WORLD!

# %%
def Isprimenumber(number:int)->bool:
    ''' this fun is check if the number is prime or not
    Args:
        number (int): The number to check

    Returns:
        bool: True if the number is prime, False otherwise
    '''
    is_prime = True
    if number <= 1:
     is_prime = False

    else:
     for i in range(2, int(number ** 0.5) + 1):
        if number % i == 0:
            is_prime = False
            break
    return is_prime

# %%
number = 29
prime= Isprimenumber (number)

if prime:
    print(f"The number {number} is prime.")
else:
    print(f"The number {number} is not prime.")
# Out:
# The number 29 is prime.

# %%
def fact(num:int)->int:
    if num == 0:
     return 1
    return num*fact(num-1)

# %%
fact(5)
# Out:
# 120

# %%
def common_divisors(num1,num2):
   minnum= min(num1,num2)
   divisor=[]
   for i in range(1,minnum +1):
      if num1 % i==0 and num2 %i ==0:
         divisor.append(i)
   return divisor

# %%
common_divisors(10,20)
# Out:
# [1, 2, 5, 10]

# %%
def reverse_string(s:str)->str:
    ''' this fun is reverse the string
    Args:
        s (str): The string to reverse

    Returns:
        str: The reversed string
    '''

    lst=s.split()
    newl=lst[::-1]
    return newl
'''فمعناها: هات العناصر كلها ولكن امشِ من الآخر للأول'''
# Out:
# 'فمعناها: هات العناصر كلها ولكن امشِ من الآخر للأول'

# %%
result = reverse_string("Hello World from Python")
for word in result:
    print(word, end=" ")
# Out:
# Python from World Hello

# %%
def reverse(s:str)->list:
    lst =s.split()
    newl=lst[::-1]
    return newl

# %%
import random
c="hkwah/xc,xzfm'lsd;lpsdfo,lsHPEWFWEM"
password = ""

for _ in range(8):
    password += random.choice(char)


print(password)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 6
#       2 c="hkwah/xc,xzfm'lsd;lpsdfo,lsHPEWFWEM"
#       3 password = ""
#       4
#       5 for _ in range(8):
# ----> 6     password += random.choice(char)
#       7
#       8
#       9 print(password)
#
# NameError: name 'char' is not defined

# %%
def generatepass(l:int):
 if l<=0:
     raise ValueError("password length must be greater than 0")
 c="hkwah/xc,xzfm'lsd;lpsdfo,lsHPEWFWEM"
 password = ""

 for _ in range(l):
         password += random.choice(char)


 return password

# %%
words=["ali","ahmed","mohamed",
       "sayed","ali","ahmed","mohamed",
       "sayed","ali","ahmed","mohamed","sayed","ali",
       "ahmed","mohamed"]
dictt={}
for i in words:
    counter=words.count(i)
    dictt[i]=counter
    counter=0

dictt
# Out:
# {'ali': 4, 'ahmed': 4, 'mohamed': 4, 'sayed': 3}

# %%
numbers=[1,2,3,4,5]
square=[num**2 for num in numbers if num %2==0]
square
# Out:
# [1, 4, 9, 16, 25]

# %%
words=["ali","ahmed","mohamed",
       "sayed","ali","ahmed","mohamed",
       "sayed","ali","ahmed","mohamed","sayed","ali",
       "ahmed","mohamed"]
dictt={}
for i in words:
    counter=words.count(i)
    dictt[i]=counter
    counter=0

dictt
# Out:
# {'ali': 4, 'ahmed': 4, 'mohamed': 4, 'sayed': 3}

# %%
responses = {
    "hello": ["Hello!", "Hi there!", "Greetings!"],
    "how are you": ["I'm doing well, thank you!", "I'm fine, how about you?"],
    "goodbye": ["Goodbye!", "See you later!", "Farewell!"],
    "default": ["I'm sorry, I didn't understand.", "Could you please rephrase that?"]
}
 
def get_response(user_input):
    for key in responses:
        if key in user_input:
            return random.choice(responses[key])
    return random.choice(responses["default"])
 
def main():
    print("chatbot : hi how i can help you!")
    while True:
        user_input = input("User:  ").lower()
        response = get_response(user_input)
        print("chatbot ", response)
       
        if user_input == "goodbye":
            break
main()
# Out:
# chatbot : hi how i can help you!
# chatbot  I'm sorry, I didn't understand.
# chatbot  Could you please rephrase that?
# chatbot  I'm sorry, I didn't understand.
# chatbot  Greetings!
# chatbot  Could you please rephrase that?
# chatbot  I'm sorry, I didn't understand.
# chatbot  I'm sorry, I didn't understand.
# chatbot  Could you please rephrase that?
# chatbot  Could you please rephrase that?
# chatbot  Could you please rephrase that?
# chatbot  I'm sorry, I didn't understand.
# chatbot  I'm sorry, I didn't understand.
# chatbot  Could you please rephrase that?
# chatbot  I'm sorry, I didn't understand.
# chatbot  Could you please rephrase that?
# chatbot  I'm sorry, I didn't understand.
# chatbot  I'm sorry, I didn't understand.
# chatbot  I'm sorry, I didn't understand.
# chatbot  I'm sorry, I didn't understand.
# chatbot  Could you please rephrase that?
# chatbot  I'm sorry, I didn't understand.
# chatbot  See you later!

# %%
try :
    5/0

except ZeroDivisionError:
    print("division by zero not allowed")
# Out:
# division by zero not allowed

# %%
n1=int (5)
n2=int(2)
res=(n1/n2)
type(res)
# Out:
# float
