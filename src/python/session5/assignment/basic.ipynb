# %%
my_tuple = (1, 2, 3)
item_to_add = 4
new_tuple = list(my_tuple)
new_tuple.append(item_to_add)
new_tuple = tuple(new_tuple)
print(new_tuple)
# Out:
# (1, 2, 3, 4)

# %%
total = 0
numbers = [5, 10, 15, 20]
for i in numbers:
    total += i

print(total)
# Out:
# 50

# %%
mult=1
numbers = [2, 3, 4]
for i in numbers:
    mult *= i

print(mult)
# Out:
# 24

# %%
numbers = [10, 3, 25, 1, 7]
min=numbers[0]
for i in range(len(numbers)):
    if numbers[i]<min :
       min=numbers[i]
       
       
print(min)
# Out:
# 1

# %%
numbers = [10, 3, 25, 1, 7]
max=numbers[0]

for i in range(len(numbers)):
    if numbers[i]>max :
       max=numbers[i]
       
       
print(max)
# Out:
# 25

# %%
words = ["hi", "a", "hello", "no", "on"]

# TODO: count strings with length >= 2
count = 0
for i in words :
    if len(i)>=2:
      count+=1

print(count)
# Out:
# 4

# %%
original = [1, 2, 3, 4]
cloned=original
print(cloned)
# Out:
# [1, 2, 3, 4]

# %%
my_set = {1, 2, 3, 4, 5}
my_set.remove(2)
print(my_set)
# Out:
# {1, 3, 4, 5}

# %%
set1 = {1, 2}
set2 = {1, 2, 3, 4}
set1.issubset(set2)
# Out:
# True

# %%
my_set = {1, 2, 3}

my_set.clear()

print(my_set)
# Out:
# set()

# %%
numbers = {10, 3, 25, 1, 7}

max=numbers[0]

for i in range(len(numbers)):
    if numbers[i]>max :
       max=numbers[i]

min=numbers[0]
for i in range(len(numbers)):
    if numbers[i]<min :
       min=numbers[i]

print("Max:", max)
print("Min:", min)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 3
#       1 numbers = {10, 3, 25, 1, 7}
#       2
# ----> 3 max=numbers[0]
#       4
#       5 for i in range(len(numbers)):
#       6     if numbers[i]>max :
#
# TypeError: 'set' object is not subscriptable
