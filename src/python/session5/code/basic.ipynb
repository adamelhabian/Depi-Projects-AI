# %%
list1 = [1, 2, 3, 4, 5]
newlist=[]
poplist=list1.pop()
newlist.append(poplist)
print(list1)
print(newlist)
# Out:
# [1, 2, 3, 4]
# [5]

# %%
list1 = [1, 2, 3, 4, 5]
del list1[:]
list1.clear()
print(list1)
# Out:
# []

# %%
str=input("Enter a string: ")
input_list = ["amit","learning","python","is","fun"]
input_list.remove(str)
print(input_list)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 3
#       1 str=input("Enter a string: ")
#       2 input_list = ["amit","learning","python","is","fun"]
# ----> 3 input_list.remove(str)
#       4 print(input_list)
#
# ValueError: list.remove(x): x not in list

# %%
input_list = ["amit","learning","python","is","fun"]
new =input_list.count("amit")
print(new)
# Out:
# 1
