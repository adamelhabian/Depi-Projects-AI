# %%
def validation(email:str):
     if email.count('@') !=1 or email.count('.') ==0 :
          return "Invalid email"
     else :
          ind=email.find('@')
          print(f"your user name is {email[:ind]}")
          dot=email.rfind('.')
          print(f"your domain is {email[ind+1:dot]}")
          if email.endswith(".com"):
               print("Commercial Domain")
          elif email.endswith(".edu"):
               print("Educational Domain")
          else:
               print("Other Domain")

# %%
\*Input Validation: Check if the input string contains exactly one "@" symbol and at least one "." 
\\after the "@" symbol. If it's not a valid email, return "Invalid email". - 
\Extract Username: Extract
\and return the part of the email before the "@" symbol. - Extract Domain: Extract and return the domain
\(the part between "@" and the last "."). - Check for Domain Ending: Check if the email ends with ".com".
\If it does, return "Commercial Domain". If it ends with ".edu", return "Educational Domain". Otherwise, 
\return "Other Domain".
//string.count() إزاي نعرف عدد مرات ظهور حرف في String
//string.index() وإزاي نعرف مكان حرف معين؟ او string.find()
//email.rfind(".") نقطة آخر

# %%
validation("tspeeh@gamil.com")
# Out:
# your user name is tspeeh
# your domain is gamil
# Commercial Domain
