# %%
print("toity");
# Out:
# toity

# %%
listone =[1,2,3,4,5,"depi", True, 3.14, 2.71, "hello", False,[1,2,3,[True]], {"name": "John", "age": 30}, (1,2,3), None]
print(listone)
# Out:
# [1, 2, 3, 4, 5, 'depi', True, 3.14, 2.71, 'hello', False, [1, 2, 3, [True]], {'name': 'John', 'age': 30}, (1, 2, 3), None]

# %%
listt=["tspeeh"]
listt.append("new item")
listt.insert(0, "first item")
listt.insert(2, 5)
listt.insert(3, 8)
listt.insert(4, 1)

listt.remove("tspeeh")
listt.pop(1)

print(listt)
# Out:
# ['first item', 8, 1, 'new item']

# %%
print(dir(list))
